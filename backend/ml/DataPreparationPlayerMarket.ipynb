# %% [markdown]
# # Data Preparation for Player Market
# This notebook is structured to align with the same header and layout as the Home page.

# %% [markdown]
# ## Header
# The header includes navigation links and a search bar, similar to the Home page.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Left Sidebar
# The left sidebar contains profile information and navigation links.

# %%
# Load the dataset
file_path = 'D:/PIDS/dataset/Decoded_PlayerMarket.csv'
df = pd.read_csv(file_path)
df.head()

# %% [markdown]
# ## Main Content
# The main content area includes data analysis and visualizations.

# %%
# Display basic information about the dataset
print(df.info())
print(df.describe())

# %% [markdown]
# ## Right Sidebar
# The right sidebar includes recent activities and additional links.

# %%
# Visualize missing values
import missingno as msno
msno.matrix(df)
# Out:
# d:\CalculSc\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\CalculSc\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\CalculSc\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
